# %% [markdown]
# # Demonstrate how to remove dupplicate value from csv

# %%
import pandas as pd
df = pd.read_csv('./data/sog2_datadict.csv')

# %%
df.describe()
# Out:
#               seqno
# count  12653.000000
# mean     211.423931
# std      115.108138
# min        1.000000
# 25%      117.000000
# 50%      207.000000
# 75%      311.000000
# max      428.000000

# %%
df.dtypes
# Out:
# seqno             int64
# object_type      object
# v_object_name    object
# object_name      object
# field_name       object
# data_type        object
# pk_fk            object
# required         object
# sample_value     object
# dtype: object

# %%
df.object_name.unique()
# Out:
# array(['SessionDefinition', 'PayorAgreement', 'Problem', 'PatientVisitID',
#        'Patient', 'Careprovider', 'ReferenceValue', 'PatientBill',
#        'PatientAddress', 'PatientVisit', 'PatientProblem', 'Location',
#        'AdmissionEvent', 'DischargeEvent', 'PatientBillableItem',
#        'PatientOrder', 'PatientBilledItem', 'BillPackage', 'PayorDetail',
#        'PatientServiceEvent', 'PatientOrderDetail', 'PrescriptionItem',
#        'BillableItem', 'InsuranceCompany', 'Service', 'PolicyMaster',
#        'PatientAllergy', 'PatientAllergicDrug', 'KIT_Vaccine_MT',
#        'InsurancePlan', 'CostCode', 'LocationProfile',
#        'PatientDeceasedDetail', 'PatientVisitCareProvider',
#        'PatientPaymentDetail', 'PinCodeMapping', 'ReferenceRelationShip',
#        'OrderSet', 'CareproviderSpecialty', 'Speciality', 'careProvider',
#        'PatientVisitPayor', 'OrderCatalogItem', 'Store', 'vBDMSOnWard',
#        'RequestDetail', 'SERVICE', 'vBDMSPatientVisit',
#        'BDMSReferralAgentContact', 'BDMSReferralMaster', 'BDMSReferrer',
#        'ROLE', 'Login', 'CareproviderLocation', 'Roleprofile',
#        'BillableItemDetail', 'AgreementDetail', 'AgreementItem',
#        'AgreementAccountDetail', 'AgreementAccountDiscount',
#        'AgreementDetailDiscount', 'AgreementItemDiscount', 'Booking',
#        'OrderCategory', 'BDMSIncomeSource', 'vBDMSTOOLAccout',
#        'ItemMaster', 'OrderSetBillableItem', 'BDMSOrderSetItemPrice',
#        'BillPackageItem', 'BDMSBillPackagePrice', 'StockGoLive',
#        'TkStockBalance', 'LocationStore', 'BDMSLocationOrderCat',
#        'patientvisit', 'ServiceLocation', 'PatientEmployerDetail',
#        'BDMSContactAgreementAccountItem', 'BDMSContactAgreementAccount',
#        'BDMSContactAgreementAccountDetail', 'Payoragreement',
#        'payordetail', 'referencevalue', 'PAtient', 'DrugTradeName',
#        'DrugCatalogItem', 'vBDMSToolBillingGrp', 'REFERENCEVALUE',
#        'vBDMSToolCarepro', 'vBDMSToolOrderBilled', 'vBDMSTOOLPayor_min',
#        'vBDMSToolDEPLoc', 'vBDMSToolPlanMin', 'vBDMSToolPlanDetail',
#        'BDMSLocationOrderSubCat', 'vBDMSResultEnter', 'vBDMSOrderBilledDF',
#        'vBDMSAdmission', 'Prescription', 'DispensedItem', 'DrugGroupItem',
#        'DrugGenericMaster', 'DrugGroup',
#        'fBDMSGetCareproviderInfoByPatientAppointment',
#        'fBDMSGetCareproviderInfo', 'fBDMSgetpatientvisitandconsult',
#        'fBDMSGetFollowUpInfo', 'BDMSLocationBillableitem',
#        'vBDMSFinalOrderTolocationBillableitem',
#        'vBDMSFinalOrderTolocationSubat', 'careprovider', 'StockAdjustment',
#        'DisposeStock', 'DisposeItemList', 'ItemIssue', 'IssuedItemList',
#        'Stock', 'STOCK', 'ItemManufacturerDetail', 'ManufactureReceipt',
#        'GRNItemList', 'OpenStock', 'GRNDetail', 'StockItemList',
#        'StoreBin', 'StoreItem', 'store', 'vBDMSToolEpisode', 'vBDMSToolHN',
#        'PatientProcedure', 'fBDMSgetAnesthssiaandMethod',
#        'vBDMSReportHeaderForDiscSUM', 'PatientPackage', 'PATIENT',
#        'PATIENTIMAGE', 'PatientDeliveryDetail', 'PatientOtherContact',
#        'PatientID', 'PatientBirthRegister', 'BirthScore',
#        'ItemAverageCost', 'Request', 'PAtientBillableItem',
#        'PatientOrderDetailHistory', 'DrugInstruction', 'Itemmaster',
#        'BDMSPharHistorySticker', 'BillingService', 'fBDMSGetDoctorR2C',
#        'fBDMSgetReferencevalue', 'vBDMSR2CToolBillingroup',
#        'vBDMSR2CToolLocation', 'vBDMSR2CToolOrderSet',
#        'vBDMSR2CToolOrderCatSubcat', 'vBDMSR2CToolPackage',
#        'PatientBilleditem', 'SaleReturnList', 'SaleReturn',
#        'fBDMSGetMEDandFinanceByVisitUIDR2C', 'PatientConsultation',
#        'fBDMSGetMEDandFinanceByVisitUID', 'ResultComponent', 'Result',
#        'ResultTextual', 'CareProviderGroup', 'Role', 'SecurityGroupRole',
#        'UIView', 'SecuredItem', 'SecuredItemPermission',
#        'SecurityGroupPermission', 'ReportTemplate', 'SecurityGroup',
#        'UIModule', 'BDMSBillableEvent', 'BDMSBillableEventNation',
#        'BDMSBillableEventItem', 'BillingServiceDetailBDMS',
#        'PatientPackageItem', 'patient', 'PatientOrderResult',
#        'PatientImage', 'PatientPersonalCarer', 'CareProvider',
#        'vBDMSPatientMaster', 'service', 'PatientProcedureTeam',
#        'PatientProcedureList', 'PatientAnestheticsDetail',
#        'Vw_AdmissionEvent', 'Billableitem', 'PatientOptometry',
#        'OpticalOrder', 'vBDMSBilledRev', 'PatientOrderResultItem', nan,
#        'FrequencyDefinition', 'vBDMSDF1', 'SS_USER', 'vw_PacDESC',
#        'PAtientAllergy', 'RequestItem', 'RequestResultLink', 'ResultItem',
#        'PatientPersonalCArer', 'PAtientADdress', 'BDMSRevDep',
#        'Permission', 'PatientExaminationData', 'DataAttribute',
#        'PatientExaminationSection', 'PatientExaminationForm',
#        'TheaterProcedureList', 'TheaterBooking', 'patientorderdetail',
#        'RadiologyModality', 'IPBooking', 'PatientAEAdmission',
#        'VW_SSH_PatientBillableItem', 'vBDMSPatientVisitPayor',
#        'VW_SSH_StrokMasterlinkBillableItem', 'CareproviderService',
#        'VW_SSH_BDMSBillableItemDetail', 'VW_SSH_PatientVisitID',
#        'PatientBillStatus', 'AppointmentRequest', 'vw_StockMaster',
#        'VW_SSH_StockMaster', 'CCHPIMASTER', 'PatientAssesment', 'CCHPI',
#        'ReferenCevalue', 'BDMSASTEMRDoctorComment', 'vBDMSPatientOrder',
#        'MedicalItem', 'PatientMedicalHistory', 'BDMSASTEMRPhysicalExam',
#        'BDMSASTEMRProgressNote', 'VW_SSH_vBDMSPatientOrder',
#        'PatientAlias', 'PatientAssementSection',
#        'PatientAssesmentAttribute', 'LocationTransfer', 'PatientORDER',
#        'REferenceValue', 'patientbill', 'ManufacturerDetail',
#        'PatientORDERResultItem', 'fBDMSGetAgeYear',
#        'fGetPatientRelationName'], dtype=object)

# %%
ndf = df.drop_duplicates(['object_name', 'field_name'])

# %%
ndf.describe()
# Out:
#              seqno
# count  2361.000000
# mean    154.312579
# std     116.575198
# min       1.000000
# 25%      62.000000
# 50%     121.000000
# 75%     241.000000
# max     428.000000

# %%
ndf.to_csv('./data/sog2_datadict_nodup.csv')

# %%
ndf.object_name.unique()
# Out:
# array(['SessionDefinition', 'PayorAgreement', 'Problem', 'PatientVisitID',
#        'Patient', 'Careprovider', 'ReferenceValue', 'PatientBill',
#        'PatientAddress', 'PatientVisit', 'PatientProblem', 'Location',
#        'AdmissionEvent', 'DischargeEvent', 'PatientBillableItem',
#        'PatientOrder', 'PatientBilledItem', 'BillPackage', 'PayorDetail',
#        'PatientServiceEvent', 'PatientOrderDetail', 'PrescriptionItem',
#        'BillableItem', 'InsuranceCompany', 'Service', 'PolicyMaster',
#        'PatientAllergy', 'PatientAllergicDrug', 'KIT_Vaccine_MT',
#        'InsurancePlan', 'CostCode', 'LocationProfile',
#        'PatientDeceasedDetail', 'PatientVisitCareProvider',
#        'PatientPaymentDetail', 'PinCodeMapping', 'ReferenceRelationShip',
#        'OrderSet', 'CareproviderSpecialty', 'Speciality', 'careProvider',
#        'PatientVisitPayor', 'OrderCatalogItem', 'Store', 'vBDMSOnWard',
#        'RequestDetail', 'SERVICE', 'vBDMSPatientVisit',
#        'BDMSReferralAgentContact', 'BDMSReferralMaster', 'BDMSReferrer',
#        'ROLE', 'Login', 'CareproviderLocation', 'Roleprofile',
#        'BillableItemDetail', 'AgreementDetail', 'AgreementItem',
#        'AgreementAccountDetail', 'AgreementAccountDiscount',
#        'AgreementDetailDiscount', 'AgreementItemDiscount', 'Booking',
#        'OrderCategory', 'BDMSIncomeSource', 'vBDMSTOOLAccout',
#        'ItemMaster', 'OrderSetBillableItem', 'BDMSOrderSetItemPrice',
#        'BillPackageItem', 'BDMSBillPackagePrice', 'StockGoLive',
#        'TkStockBalance', 'LocationStore', 'BDMSLocationOrderCat',
#        'patientvisit', 'ServiceLocation', 'PatientEmployerDetail',
#        'BDMSContactAgreementAccountItem', 'BDMSContactAgreementAccount',
#        'BDMSContactAgreementAccountDetail', 'Payoragreement',
#        'payordetail', 'referencevalue', 'PAtient', 'DrugTradeName',
#        'DrugCatalogItem', 'vBDMSToolBillingGrp', 'REFERENCEVALUE',
#        'vBDMSToolCarepro', 'vBDMSToolOrderBilled', 'vBDMSTOOLPayor_min',
#        'vBDMSToolDEPLoc', 'vBDMSToolPlanMin', 'vBDMSToolPlanDetail',
#        'BDMSLocationOrderSubCat', 'vBDMSResultEnter', 'vBDMSOrderBilledDF',
#        'vBDMSAdmission', 'Prescription', 'DispensedItem', 'DrugGroupItem',
#        'DrugGenericMaster', 'DrugGroup',
#        'fBDMSGetCareproviderInfoByPatientAppointment',
#        'fBDMSGetCareproviderInfo', 'fBDMSgetpatientvisitandconsult',
#        'fBDMSGetFollowUpInfo', 'BDMSLocationBillableitem',
#        'vBDMSFinalOrderTolocationBillableitem',
#        'vBDMSFinalOrderTolocationSubat', 'careprovider', 'StockAdjustment',
#        'DisposeStock', 'DisposeItemList', 'ItemIssue', 'IssuedItemList',
#        'Stock', 'STOCK', 'ItemManufacturerDetail', 'ManufactureReceipt',
#        'GRNItemList', 'OpenStock', 'GRNDetail', 'StockItemList',
#        'StoreBin', 'StoreItem', 'store', 'vBDMSToolEpisode', 'vBDMSToolHN',
#        'PatientProcedure', 'fBDMSgetAnesthssiaandMethod',
#        'vBDMSReportHeaderForDiscSUM', 'PatientPackage', 'PATIENT',
#        'PATIENTIMAGE', 'PatientDeliveryDetail', 'PatientOtherContact',
#        'PatientID', 'PatientBirthRegister', 'BirthScore',
#        'ItemAverageCost', 'Request', 'PAtientBillableItem',
#        'PatientOrderDetailHistory', 'DrugInstruction', 'Itemmaster',
#        'BDMSPharHistorySticker', 'BillingService', 'fBDMSGetDoctorR2C',
#        'fBDMSgetReferencevalue', 'vBDMSR2CToolBillingroup',
#        'vBDMSR2CToolLocation', 'vBDMSR2CToolOrderSet',
#        'vBDMSR2CToolOrderCatSubcat', 'vBDMSR2CToolPackage',
#        'PatientBilleditem', 'SaleReturnList', 'SaleReturn',
#        'fBDMSGetMEDandFinanceByVisitUIDR2C', 'PatientConsultation',
#        'fBDMSGetMEDandFinanceByVisitUID', 'ResultComponent', 'Result',
#        'ResultTextual', 'CareProviderGroup', 'Role', 'SecurityGroupRole',
#        'UIView', 'SecuredItem', 'SecuredItemPermission',
#        'SecurityGroupPermission', 'ReportTemplate', 'SecurityGroup',
#        'UIModule', 'BDMSBillableEvent', 'BDMSBillableEventNation',
#        'BDMSBillableEventItem', 'BillingServiceDetailBDMS',
#        'PatientPackageItem', 'patient', 'PatientOrderResult',
#        'PatientImage', 'PatientPersonalCarer', 'CareProvider',
#        'vBDMSPatientMaster', 'service', 'PatientProcedureTeam',
#        'PatientProcedureList', 'PatientAnestheticsDetail',
#        'Vw_AdmissionEvent', 'Billableitem', 'PatientOptometry',
#        'OpticalOrder', 'vBDMSBilledRev', 'PatientOrderResultItem', nan,
#        'FrequencyDefinition', 'vBDMSDF1', 'SS_USER', 'vw_PacDESC',
#        'PAtientAllergy', 'RequestItem', 'RequestResultLink', 'ResultItem',
#        'PatientPersonalCArer', 'PAtientADdress', 'BDMSRevDep',
#        'Permission', 'PatientExaminationData', 'DataAttribute',
#        'PatientExaminationSection', 'PatientExaminationForm',
#        'TheaterProcedureList', 'TheaterBooking', 'patientorderdetail',
#        'RadiologyModality', 'IPBooking', 'PatientAEAdmission',
#        'VW_SSH_PatientBillableItem', 'vBDMSPatientVisitPayor',
#        'VW_SSH_StrokMasterlinkBillableItem', 'CareproviderService',
#        'VW_SSH_BDMSBillableItemDetail', 'VW_SSH_PatientVisitID',
#        'PatientBillStatus', 'AppointmentRequest', 'vw_StockMaster',
#        'VW_SSH_StockMaster', 'CCHPIMASTER', 'PatientAssesment', 'CCHPI',
#        'ReferenCevalue', 'BDMSASTEMRDoctorComment', 'vBDMSPatientOrder',
#        'MedicalItem', 'PatientMedicalHistory', 'BDMSASTEMRPhysicalExam',
#        'BDMSASTEMRProgressNote', 'VW_SSH_vBDMSPatientOrder',
#        'PatientAlias', 'PatientAssementSection',
#        'PatientAssesmentAttribute', 'LocationTransfer', 'PatientORDER',
#        'REferenceValue', 'patientbill', 'ManufacturerDetail',
#        'PatientORDERResultItem', 'fBDMSGetAgeYear',
#        'fGetPatientRelationName'], dtype=object)

# %%
import matplotlib.pyplot as plot

# %%
#plot_data = ndf['object_name'] df.groupby(['col1', 'col2']).
plot_data =ndf[['object_name','field_name']]

# %%
plot_data
# Out:
#                                        field_name
# object_name
# AdmissionEvent                                  9
# AgreementAccountDetail                         10
# AgreementAccountDiscount                        9
# AgreementDetail                                10
# AgreementDetailDiscount                         9
# AgreementItem                                   9
# AgreementItemDiscount                           9
# AppointmentRequest                              6
# BDMSASTEMRDoctorComment                        12
# BDMSASTEMRPhysicalExam                          7
# BDMSASTEMRProgressNote                         12
# BDMSBillPackagePrice                            5
# BDMSBillableEvent                              10
# BDMSBillableEventItem                           5
# BDMSBillableEventNation                         4
# BDMSContactAgreementAccount                     5
# BDMSContactAgreementAccountDetail               4
# BDMSContactAgreementAccountItem                 3
# BDMSIncomeSource                                4
# BDMSLocationBillableitem                        8
# BDMSLocationOrderCat                            3
# BDMSLocationOrderSubCat                         9
# BDMSOrderSetItemPrice                           6
# BDMSPharHistorySticker                         18
# BDMSReferralAgentContact                        4
# BDMSReferralMaster                             12
# BDMSReferrer                                    5
# BDMSRevDep                                      2
# BillPackage                                    13
# BillPackageItem                                 9
# ...                                           ...
# vBDMSAdmission                                  3
# vBDMSBilledRev                                 13
# vBDMSDF1                                       40
# vBDMSFinalOrderTolocationBillableitem          11
# vBDMSFinalOrderTolocationSubat                 11
# vBDMSOnWard                                    12
# vBDMSOrderBilledDF                             42
# vBDMSPatientMaster                             28
# vBDMSPatientOrder                               9
# vBDMSPatientVisit                              66
# vBDMSPatientVisitPayor                         10
# vBDMSR2CToolBillingroup                         6
# vBDMSR2CToolLocation                            6
# vBDMSR2CToolOrderCatSubcat                      6
# vBDMSR2CToolOrderSet                           15
# vBDMSR2CToolPackage                             9
# vBDMSReportHeaderForDiscSUM                    18
# vBDMSResultEnter                                6
# vBDMSTOOLAccout                                 6
# vBDMSTOOLPayor_min                              7
# vBDMSToolBillingGrp                             5
# vBDMSToolCarepro                                3
# vBDMSToolDEPLoc                                 5
# vBDMSToolEpisode                                9
# vBDMSToolHN                                    10
# vBDMSToolOrderBilled                           40
# vBDMSToolPlanDetail                            10
# vBDMSToolPlanMin                                4
# vw_PacDESC                                      4
# vw_StockMaster                                 10
#
# [250 rows x 1 columns]

# %%
#plot_data= plot_data.groupby('object_name').count()

# %%
#plot_data.plot(kind='bar')
#plot_data.sort_values()[-10:].plot(kind='bar')
plot.title("Number of Field being use/table")
plot.ylabel("Table Name")
#plot.kind('bar')
plot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-2c53cf009a64> in <module>()
#       1 #plot_data.plot(kind='bar')
# ----> 2 plot_data.sort_values()[-10:].plot(kind='bar')
#       3 plot.title("Number of Field being use/table")
#       4 plot.ylabel("Table Name")
#       5 #plot.kind('bar')
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
